# %%
import matplotlib.pyplot as plt
import seaborn as sns  
import numpy as np
import pandas as pd

# %% [markdown]
# ENGAGEMENT ANALYSIS

# %%
#Loading urls and data-likes and comments


# Posts before co-branding
before_co_branding_posts = {
    "https://www.instagram.com/p/BPciBX0lxYt/?hl=en": (37375, 103,  "19.01.2017", "Before Co-Branding_id_1"),
    "https://www.instagram.com/p/BPa_5lEFaIW/?hl=en": (115488, 904, "18.01.2017", "Before Co-Branding_id_2"),
    "https://www.instagram.com/p/BPaZadqlm9O/?hl=en": (45449, 95, "18.01.2016", "Before Co-Branding_id_3"),
    "https://www.instagram.com/p/BPYCH5RAYad/?hl=en": (71796, 196, "17.01.2017", "Before Co-Branding_id_4"),
    "https://www.instagram.com/p/BPQDbDhANS1/?hl=en": (22346, 141, "14.01.2017", "Before Co-Branding_id_5")
}

# Main posts
co_branding_posts = {
  "https://www.instagram.com/p/BPcvYTDFB9e/?hl=en": (97254, 3313, "19.01.2017", "Co-Branding_id_1"),
  "https://www.instagram.com/p/BPc0Dpjllv_/?hl=en": (45373, 220, "19.01.2017", "Co-Branding_id_2")
}

# Posts after co-branding
after_co_branding_posts = {
    "https://www.instagram.com/p/BPdA4lkAxpx/?hl=en": (32181, 123,  "19.01.2017", "After Co-Branding_id_1"),
    "https://www.instagram.com/p/BPdMVPegQQb/?hl=en": (28393, 89, "19.01.2017", "After Co-Branding_id_2"),
    "https://www.instagram.com/p/BPddsj7g7-z/?hl=en": (34647, 180, "19.01.2017", "After Co-Branding_id_3"),
    "https://www.instagram.com/p/BPdoHuYAjPg/?hl=en": (49620, 199, "19.01.2017", "After Co-Branding_id_4"),
    "https://www.instagram.com/p/BPduYt2AmWw/?hl=en": (29431, 90, "20.01.2017", "After Co-Branding_id_5")
}

posts = { **before_co_branding_posts, **co_branding_posts, **after_co_branding_posts}

# Create DataFrame
posts = pd.DataFrame.from_dict(posts,  orient='index', columns=['Likes', "Comments", 'Date', 'Post'])
posts
# Out:
#                                                  Likes  Comments        Date  \
# https://www.instagram.com/p/BPciBX0lxYt/?hl=en   37375       103  19.01.2017
# https://www.instagram.com/p/BPa_5lEFaIW/?hl=en  115488       904  18.01.2017
# https://www.instagram.com/p/BPaZadqlm9O/?hl=en   45449        95  18.01.2016
# https://www.instagram.com/p/BPYCH5RAYad/?hl=en   71796       196  17.01.2017
# https://www.instagram.com/p/BPQDbDhANS1/?hl=en   22346       141  14.01.2017
# https://www.instagram.com/p/BPcvYTDFB9e/?hl=en   97254      3313  19.01.2017
# https://www.instagram.com/p/BPc0Dpjllv_/?hl=en   45373       220  19.01.2017
# https://www.instagram.com/p/BPdA4lkAxpx/?hl=en   32181       123  19.01.2017
# https://www.instagram.com/p/BPdMVPegQQb/?hl=en   28393        89  19.01.2017
# https://www.instagram.com/p/BPddsj7g7-z/?hl=en   34647       180  19.01.2017
# https://www.instagram.com/p/BPdoHuYAjPg/?hl=en   49620       199  19.01.2017
# https://www.instagram.com/p/BPduYt2AmWw/?hl=en   29431        90  20.01.2017
#
#                                                                    Post
# https://www.instagram.com/p/BPciBX0lxYt/?hl=en  Before Co-Branding_id_1
# https://www.instagram.com/p/BPa_5lEFaIW/?hl=en  Before Co-Branding_id_2
# https://www.instagram.com/p/BPaZadqlm9O/?hl=en  Before Co-Branding_id_3
# https://www.instagram.com/p/BPYCH5RAYad/?hl=en  Before Co-Branding_id_4
# https://www.instagram.com/p/BPQDbDhANS1/?hl=en  Before Co-Branding_id_5
# https://www.instagram.com/p/BPcvYTDFB9e/?hl=en         Co-Branding_id_1
# https://www.instagram.com/p/BPc0Dpjllv_/?hl=en         Co-Branding_id_2
# https://www.instagram.com/p/BPdA4lkAxpx/?hl=en   After Co-Branding_id_1
# https://www.instagram.com/p/BPdMVPegQQb/?hl=en   After Co-Branding_id_2
# https://www.instagram.com/p/BPddsj7g7-z/?hl=en   After Co-Branding_id_3
# https://www.instagram.com/p/BPdoHuYAjPg/?hl=en   After Co-Branding_id_4
# https://www.instagram.com/p/BPduYt2AmWw/?hl=en   After Co-Branding_id_5

# %%
#Loading urls and data-likes and comments


# Posts before co-branding
before_co_branding_posts = {
    "https://www.instagram.com/p/BPciBX0lxYt/?hl=en": (37375, 103,  "19.01.2017", "Before Co-Branding"),
    "https://www.instagram.com/p/BPa_5lEFaIW/?hl=en": (115488, 904, "18.01.2017", "Before Co-Branding"),
    "https://www.instagram.com/p/BPaZadqlm9O/?hl=en": (45449, 95, "18.01.2016", "Before Co-Branding"),
    "https://www.instagram.com/p/BPYCH5RAYad/?hl=en": (71796, 196, "17.01.2017", "Before Co-Branding"),
    "https://www.instagram.com/p/BPQDbDhANS1/?hl=en": (22346, 141, "14.01.2017", "Before Co-Branding")
}

# Main posts
co_branding_posts = {
  "https://www.instagram.com/p/BPcvYTDFB9e/?hl=en": (97254, 3313, "19.01.2017", "Co-Branding"),
  "https://www.instagram.com/p/BPc0Dpjllv_/?hl=en": (45373, 220, "19.01.2017", "Co-Branding")
}

# Posts after co-branding
after_co_branding_posts = {
    "https://www.instagram.com/p/BPdA4lkAxpx/?hl=en": (32181, 123,  "19.01.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BPdMVPegQQb/?hl=en": (28393, 89, "19.01.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BPddsj7g7-z/?hl=en": (34647, 180, "19.01.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BPdoHuYAjPg/?hl=en": (49620, 199, "19.01.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BPduYt2AmWw/?hl=en": (29431, 90, "20.01.2017", "After Co-Branding")
}

posts_plot = { **before_co_branding_posts, **co_branding_posts, **after_co_branding_posts}

# Create DataFrame
posts_plot = pd.DataFrame.from_dict(posts_plot,  orient='index', columns=['Likes', "Comments", 'Date', 'Post'])
posts_plot
# Out:
#                                                  Likes  Comments        Date  \
# https://www.instagram.com/p/BPciBX0lxYt/?hl=en   37375       103  19.01.2017
# https://www.instagram.com/p/BPa_5lEFaIW/?hl=en  115488       904  18.01.2017
# https://www.instagram.com/p/BPaZadqlm9O/?hl=en   45449        95  18.01.2016
# https://www.instagram.com/p/BPYCH5RAYad/?hl=en   71796       196  17.01.2017
# https://www.instagram.com/p/BPQDbDhANS1/?hl=en   22346       141  14.01.2017
# https://www.instagram.com/p/BPcvYTDFB9e/?hl=en   97254      3313  19.01.2017
# https://www.instagram.com/p/BPc0Dpjllv_/?hl=en   45373       220  19.01.2017
# https://www.instagram.com/p/BPdA4lkAxpx/?hl=en   32181       123  19.01.2017
# https://www.instagram.com/p/BPdMVPegQQb/?hl=en   28393        89  19.01.2017
# https://www.instagram.com/p/BPddsj7g7-z/?hl=en   34647       180  19.01.2017
# https://www.instagram.com/p/BPdoHuYAjPg/?hl=en   49620       199  19.01.2017
# https://www.instagram.com/p/BPduYt2AmWw/?hl=en   29431        90  20.01.2017
#
#                                                               Post
# https://www.instagram.com/p/BPciBX0lxYt/?hl=en  Before Co-Branding
# https://www.instagram.com/p/BPa_5lEFaIW/?hl=en  Before Co-Branding
# https://www.instagram.com/p/BPaZadqlm9O/?hl=en  Before Co-Branding
# https://www.instagram.com/p/BPYCH5RAYad/?hl=en  Before Co-Branding
# https://www.instagram.com/p/BPQDbDhANS1/?hl=en  Before Co-Branding
# https://www.instagram.com/p/BPcvYTDFB9e/?hl=en         Co-Branding
# https://www.instagram.com/p/BPc0Dpjllv_/?hl=en         Co-Branding
# https://www.instagram.com/p/BPdA4lkAxpx/?hl=en   After Co-Branding
# https://www.instagram.com/p/BPdMVPegQQb/?hl=en   After Co-Branding
# https://www.instagram.com/p/BPddsj7g7-z/?hl=en   After Co-Branding
# https://www.instagram.com/p/BPdoHuYAjPg/?hl=en   After Co-Branding
# https://www.instagram.com/p/BPduYt2AmWw/?hl=en   After Co-Branding

# %%
# Plotting
plt.figure(figsize=(10,6))

# Plotting likes
bars = plt.bar(posts['Post'], posts['Likes'], color='grey', label='Likes')

# Adding labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             '%d' % int(height), ha='center', va='bottom')

# Adding labels and title
plt.xlabel('Post')
plt.ylabel('Count')
plt.title('Likes for Different Posts')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

# Plotting likes
bars = plt.bar(posts['Post'], posts['Comments'], color='grey', label='Comments')

# Adding labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             '%d' % int(height), ha='center', va='bottom')

# Adding labels and title
plt.xlabel('Post')
plt.ylabel('Count')
plt.title('Comments for Different Posts')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
# Calculate likes, comments per category
df_plot = posts_plot.groupby('Post')[['Likes', 'Comments']].sum()


# Define the desired order of categories
desired_order = ['Before Co-Branding', 'Co-Branding', 'After Co-Branding']

# Sort the total_engagement_per_category DataFrame based on the desired order
df_plot = df_plot.reindex(desired_order)

df_plot
# Out:
#                      Likes  Comments
# Post
# Before Co-Branding  292454      1439
# Co-Branding         142627      3533
# After Co-Branding   174272       681

# %% [markdown]
# Likes Analysis

# %%
# Plot the sum Likes per category
ax = df_plot['Likes'].plot(kind='bar', color='grey')
plt.title('Total Likes Per Category')
plt.xlabel('Post')
plt.ylabel('Likes')
plt.xticks(rotation=45)


# Add value labels to the bars
for i, v in enumerate(df_plot['Likes']):
    ax.text(i, v + 2000, str(v), ha='center', va='bottom')

plt.show()

# %%
# Calculate for each category
mean_likes = posts_plot.groupby('Post')['Likes'].agg(['mean'])
# Create a DataFrame with relevant data for comparison
comparison_likes = mean_likes.loc[['Before Co-Branding', 'Co-Branding', 'After Co-Branding']]
comparison_likes
# Out:
#                        mean
# Post
# Before Co-Branding  58490.8
# Co-Branding         71313.5
# After Co-Branding   34854.4

# %%
# Reordering the DataFrame based on the desired order of categories
desired_order = ['Before Co-Branding', 'Co-Branding', 'After Co-Branding']
mean_likes = mean_likes.reindex(desired_order)

# Plotting
ax = mean_likes.plot(kind='bar',color ="grey", figsize=(10, 6))
plt.title('Mean Likes for Each Category')
plt.xlabel('Category')
plt.ylabel('Likes')
plt.xticks(rotation=45)
plt.legend(title='Statistic')

for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), 
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
mean_likes = {
    'Before Co-Branding': 58490,
    'Co-Branding': 71313,
    'After Co-Branding': 34854
}

# Calculate the change in mean comments from 'Before Co-Branding' to 'Co-Branding'
change_comments_before_co_branding_percent = ((mean_likes['Co-Branding'] - mean_likes['Before Co-Branding']) / mean_likes['Before Co-Branding']) * 100
change_comments_co_before_branding_absolute = mean_likes['Co-Branding'] - mean_likes['Before Co-Branding']

# Calculate the change in mean comments  from 'Co-Branding' to 'After Co-Branding'
change_comments_after_co_branding_percent = ((mean_likes['After Co-Branding'] - mean_likes['Co-Branding']) / mean_likes['Co-Branding']) * 100
change_comments_after_co_branding_absolute = mean_likes['After Co-Branding'] - mean_likes['Co-Branding']

print("Change in mean likes from 'Before Co-Branding' to 'Co-Branding': {:.2f}% ({:.2f} likes)".format(change_comments_before_co_branding_percent, change_comments_co_before_branding_absolute))
print("Change in mean likes from 'Co-Branding' to 'After Co-Branding': {:.2f}% ({:.2f} likes)".format(change_comments_after_co_branding_percent, change_comments_after_co_branding_absolute))
# Out:
# Change in mean likes from 'Before Co-Branding' to 'Co-Branding': 21.92% (12823.00 likes)
# Change in mean likes from 'Co-Branding' to 'After Co-Branding': -51.13% (-36459.00 likes)

# %%
# PLOTTING LIKES CHANGE

# Calculate the changes in mean likes
changes_percent_likes = {
    'Before to Co-Branding': ((mean_likes['Co-Branding'] - mean_likes['Before Co-Branding']) / mean_likes['Before Co-Branding']) * 100,
    'Co-Branding to After': ((mean_likes['After Co-Branding'] - mean_likes['Co-Branding']) / mean_likes['Co-Branding']) * 100
}

changes_absolute_likes = {
    'Before Co-Branding': mean_likes['Co-Branding'] - mean_likes['Before Co-Branding'],
    'After Co-Branding': mean_likes['After Co-Branding'] - mean_likes['Co-Branding']
}

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Bar plot for percentage changes
ax[0].bar(changes_percent_likes.keys(), changes_percent_likes.values(), color=['grey', 'grey'])
ax[0].set_ylabel('Percentage Change')
ax[0].set_title('Percentage Change in Mean Likes')
for i, v in enumerate(changes_percent_likes.values()):
    ax[0].text(i, v, f"{v:.2f}%", ha='center', va='bottom')

# Bar plot for absolute changes
ax[1].bar(changes_absolute_likes.keys(), changes_absolute_likes.values(), color=['grey', 'grey'])
ax[1].set_ylabel('Absolute Change')
ax[1].set_title('Absolute Change in Mean Likes')
for i, v in enumerate(changes_absolute_likes.values()):
    ax[1].text(i, v, f"{v:.2f}", ha='center', va='bottom')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Comments

# %%
# Plot the sum Comments per category
ax = df_plot['Comments'].plot(kind='bar', color='grey')
plt.title('Total Comments Per Category')
plt.xlabel('Post')
plt.ylabel('Comments')
plt.xticks(rotation=45)


for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), 
                textcoords='offset points')
plt.show()

# %%
# Calculate for each category
mean_comments = posts_plot.groupby('Post')['Comments'].agg(['mean'])
# Create a DataFrame with relevant data for comparison
comparison_comments = mean_comments.loc[['Before Co-Branding', 'Co-Branding', 'After Co-Branding']]

comparison_comments
# Out:
#                       mean
# Post
# Before Co-Branding   287.8
# Co-Branding         1766.5
# After Co-Branding    136.2

# %%
# Reordering the DataFrame based on the desired order of categories
desired_order = ['Before Co-Branding', 'Co-Branding', 'After Co-Branding']
mean_comments = mean_comments.reindex(desired_order)

# Plotting
ax = mean_comments.plot(kind='bar',color ="grey", figsize=(10, 6))
plt.title('Mean Comments for Each Category')
plt.xlabel('Category')
plt.ylabel('Comments')
plt.xticks(rotation=45)
plt.legend(title='Statistic')


for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), 
                textcoords='offset points')
plt.tight_layout()
plt.show()

# %%
mean_comments = {
    'Before Co-Branding': 287,
    'Co-Branding': 1766,
    'After Co-Branding': 136
}

# Calculate the change in mean comments from 'Before Co-Branding' to 'Co-Branding'
change_comments_before_co_branding_percent = ((mean_comments['Co-Branding'] - mean_comments['Before Co-Branding']) / mean_comments['Before Co-Branding']) * 100
change_comments_co_before_branding_absolute = mean_comments['Co-Branding'] - mean_comments['Before Co-Branding']

# Calculate the change in mean comments  from 'Co-Branding' to 'After Co-Branding'
change_comments_after_co_branding_percent = ((mean_comments['After Co-Branding'] - mean_comments['Co-Branding']) / mean_comments['Co-Branding']) * 100
change_comments_after_co_branding_absolute = mean_comments['After Co-Branding'] - mean_comments['Co-Branding']

print("Change in mean comments from 'Before Co-Branding' to 'Co-Branding': {:.2f}% ({:.2f} comments)".format(change_comments_before_co_branding_percent, change_comments_co_before_branding_absolute))
print("Change in mean comments from 'Co-Branding' to 'After Co-Branding': {:.2f}% ({:.2f} comments)".format(change_comments_after_co_branding_percent, change_comments_after_co_branding_absolute))
# Out:
# Change in mean comments from 'Before Co-Branding' to 'Co-Branding': 515.33% (1479.00 comments)
# Change in mean comments from 'Co-Branding' to 'After Co-Branding': -92.30% (-1630.00 comments)

# %%
# PLOTTING LIKES CHANGE

# Calculate the changes in median likes
changes_percent_comments = {
    'Before to Co-Branding': ((mean_comments['Co-Branding'] - mean_comments['Before Co-Branding']) / mean_comments['Before Co-Branding']) * 100,
    'Co-Branding to After': ((mean_comments['After Co-Branding'] - mean_comments['Co-Branding']) / mean_comments['Co-Branding']) * 100
}

changes_absolute_comments = {
    'Before Co-Branding': mean_comments['Co-Branding'] - mean_comments['Before Co-Branding'],
    'After Co-Branding': mean_comments['After Co-Branding'] - mean_comments['Co-Branding']
}

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Bar plot for percentage changes
ax[0].bar(changes_percent_comments.keys(), changes_percent_comments.values(), color=['grey', 'grey'])
ax[0].set_ylabel('Percentage Change')
ax[0].set_title('Percentage Change in Mean Comments')
for i, v in enumerate(changes_percent_comments.values()):
    ax[0].text(i, v, f"{v:.2f}%", ha='center', va='bottom')

# Bar plot for absolute changes
ax[1].bar(changes_absolute_comments.keys(), changes_absolute_comments.values(), color=['grey', 'grey'])
ax[1].set_ylabel('Absolute Change')
ax[1].set_title('Absolute Change in Mean Comments')
for i, v in enumerate(changes_absolute_comments.values()):
    ax[1].text(i, v, f"{v:.2f}", ha='center', va='bottom')

# Show plot
plt.tight_layout()
plt.show()
