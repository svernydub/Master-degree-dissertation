# %%
import matplotlib.pyplot as plt
import seaborn as sns  
import numpy as np
import pandas as pd

# %% [markdown]
# ENGAGEMENT ANALYSIS

# %%
#Loading urls and data-likes and comments


# Posts before co-branding
before_co_branding_posts = {
    "https://www.instagram.com/p/BPc66nQB6Lb/?hl=en": (98963, 1830,  "19.01.2017", "Before Co-Branding_id_1"),
    "https://www.instagram.com/p/BPSk-MUBzIP/?hl=en": (106123, 467, "15.01.2017", "Before Co-Branding_id_2"),
    "https://www.instagram.com/p/BOAVCBpBSvH/?hl=en": (110151, 1831, "04.12.2016", "Before Co-Branding_id_3"),
    "https://www.instagram.com/p/BNcFC70B0dE/?hl=en": (95190, 1761, "30.11.2016", "Before Co-Branding_id_4"),
    "https://www.instagram.com/p/BNcEUiMhkrq/?hl=en": (40652, 767, "30.11.2016", "Before Co-Branding_id_5")
}

# Main posts
co_branding_posts = {
    "https://www.instagram.com/p/BPc7H-0BRSs/?taken-by=supremenewyork": (127540, 1803, "19.01.2017", "Co-Branding_id_1"),
    "https://www.instagram.com/p/BPc7UsMhxCd/?taken-by=supremenewyork": (234441, 6928, "19.01.2017", "Co-Branding_id_2")
}

# Posts after co-branding
after_co_branding_posts = {
    "https://www.instagram.com/p/BP-SZRGh7zx/?hl=en": (84796, 1231, "01.02.2017", "After Co-Branding_id_1"),
    "https://www.instagram.com/p/BQdLv5nB9cW/?hl=en": (79955, 707, "13.02.2017", "After Co-Branding_id_2"),
    "https://www.instagram.com/p/BQdMANjhSyS/?hl=en": (102337, 1531, "13.02.2017", "After Co-Branding_id_3"),
    "https://www.instagram.com/p/BQdMK24BI6D/?hl=en": (49620, 370, "13.02.2017", "After Co-Branding_id_4"),
    "https://www.instagram.com/p/BQdg7FRBRYS/?hl=en": (81854, 764, "13.02.2017", "After Co-Branding_id_5")
}

posts = { **before_co_branding_posts, **co_branding_posts, **after_co_branding_posts}

# Create DataFrame
posts = pd.DataFrame.from_dict(posts,  orient='index', columns=['Likes', "Comments", 'Date', 'Post'])


posts
# Out:
#                                                      Likes  Comments  \
# https://www.instagram.com/p/BPc66nQB6Lb/?hl=en       98963      1830
# https://www.instagram.com/p/BPSk-MUBzIP/?hl=en      106123       467
# https://www.instagram.com/p/BOAVCBpBSvH/?hl=en      110151      1831
# https://www.instagram.com/p/BNcFC70B0dE/?hl=en       95190      1761
# https://www.instagram.com/p/BNcEUiMhkrq/?hl=en       40652       767
# https://www.instagram.com/p/BPc7H-0BRSs/?taken-...  127540      1803
# https://www.instagram.com/p/BPc7UsMhxCd/?taken-...  234441      6928
# https://www.instagram.com/p/BP-SZRGh7zx/?hl=en       84796      1231
# https://www.instagram.com/p/BQdLv5nB9cW/?hl=en       79955       707
# https://www.instagram.com/p/BQdMANjhSyS/?hl=en      102337      1531
# https://www.instagram.com/p/BQdMK24BI6D/?hl=en       49620       370
# https://www.instagram.com/p/BQdg7FRBRYS/?hl=en       81854       764
#
#                                                           Date  \
# ...

# %%
# Combine all posts
all_posts = {**co_branding_posts, **before_co_branding_posts, **after_co_branding_posts}

# Create DataFrame
df_main = pd.DataFrame.from_dict(all_posts, orient='index', columns=['Likes', "Comments", 'Date', 'Category'])
df_main.index.name = 'URL'

# Convert 'Date' column to datetime
df_main['Date'] = pd.to_datetime(df_main['Date'], format='%d.%m.%Y')

# Reset index to move 'URL' to a column
df_main.reset_index(inplace=True)

# Reorder the columns
df_main = df_main[['URL', 'Date', 'Category', 'Likes', 'Comments']]

df_main
# Out:
#                                                   URL       Date  \
# 0   https://www.instagram.com/p/BPc7H-0BRSs/?taken... 2017-01-19
# 1   https://www.instagram.com/p/BPc7UsMhxCd/?taken... 2017-01-19
# 2      https://www.instagram.com/p/BPc66nQB6Lb/?hl=en 2017-01-19
# 3      https://www.instagram.com/p/BPSk-MUBzIP/?hl=en 2017-01-15
# 4      https://www.instagram.com/p/BOAVCBpBSvH/?hl=en 2016-12-04
# 5      https://www.instagram.com/p/BNcFC70B0dE/?hl=en 2016-11-30
# 6      https://www.instagram.com/p/BNcEUiMhkrq/?hl=en 2016-11-30
# 7      https://www.instagram.com/p/BP-SZRGh7zx/?hl=en 2017-02-01
# 8      https://www.instagram.com/p/BQdLv5nB9cW/?hl=en 2017-02-13
# 9      https://www.instagram.com/p/BQdMANjhSyS/?hl=en 2017-02-13
# 10     https://www.instagram.com/p/BQdMK24BI6D/?hl=en 2017-02-13
# 11     https://www.instagram.com/p/BQdg7FRBRYS/?hl=en 2017-02-13
#
#                    Category   Likes  Comments
# 0          Co-Branding_id_1  127540      1803
# ...

# %%
#Loading urls and data-likes and comments


# Posts before co-branding
before_co_branding_posts_plot = {
    "https://www.instagram.com/p/BPc66nQB6Lb/?hl=en": (98963, 1830,  "19.01.2017", "Before Co-Branding"),
    "https://www.instagram.com/p/BPSk-MUBzIP/?hl=en": (106123, 467, "15.01.2017", "Before Co-Branding"),
    "https://www.instagram.com/p/BOAVCBpBSvH/?hl=en": (110151, 1831, "04.12.2016", "Before Co-Branding"),
    "https://www.instagram.com/p/BNcFC70B0dE/?hl=en": (95190, 1761, "30.11.2016", "Before Co-Branding"),
    "https://www.instagram.com/p/BNcEUiMhkrq/?hl=en": (40652, 767, "30.11.2016", "Before Co-Branding")
}

# Main posts
co_branding_posts_plot = {
    "https://www.instagram.com/p/BPc7H-0BRSs/?taken-by=supremenewyork": (127540, 1803, "19.01.2017", "Co-Branding"),
    "https://www.instagram.com/p/BPc7UsMhxCd/?taken-by=supremenewyork": (234441, 6928, "19.01.2017", "Co-Branding")
}

# Posts after co-branding
after_co_branding_posts_plot = {
    "https://www.instagram.com/p/BP-SZRGh7zx/?hl=en": (84796, 1231, "01.02.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BQdLv5nB9cW/?hl=en": (79955, 707, "13.02.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BQdMANjhSyS/?hl=en": (102337, 1531, "13.02.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BQdMK24BI6D/?hl=en": (49620, 370, "13.02.2017", "After Co-Branding"),
    "https://www.instagram.com/p/BQdg7FRBRYS/?hl=en": (81854, 764, "13.02.2017", "After Co-Branding")
}

posts_plot = { **before_co_branding_posts_plot, **co_branding_posts_plot, **after_co_branding_posts_plot}

# Create DataFrame
posts_plot = pd.DataFrame.from_dict(posts_plot,  orient='index', columns=['Likes', "Comments", 'Date', 'Post'])
posts_plot
# Out:
#                                                      Likes  Comments  \
# https://www.instagram.com/p/BPc66nQB6Lb/?hl=en       98963      1830
# https://www.instagram.com/p/BPSk-MUBzIP/?hl=en      106123       467
# https://www.instagram.com/p/BOAVCBpBSvH/?hl=en      110151      1831
# https://www.instagram.com/p/BNcFC70B0dE/?hl=en       95190      1761
# https://www.instagram.com/p/BNcEUiMhkrq/?hl=en       40652       767
# https://www.instagram.com/p/BPc7H-0BRSs/?taken-...  127540      1803
# https://www.instagram.com/p/BPc7UsMhxCd/?taken-...  234441      6928
# https://www.instagram.com/p/BP-SZRGh7zx/?hl=en       84796      1231
# https://www.instagram.com/p/BQdLv5nB9cW/?hl=en       79955       707
# https://www.instagram.com/p/BQdMANjhSyS/?hl=en      102337      1531
# https://www.instagram.com/p/BQdMK24BI6D/?hl=en       49620       370
# https://www.instagram.com/p/BQdg7FRBRYS/?hl=en       81854       764
#
#                                                           Date  \
# ...

# %%
# Plotting
plt.figure(figsize=(10,6))

# Plotting likes
bars = plt.bar(posts['Post'], posts['Likes'], color='grey', label='Likes')

# Adding labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             '%d' % int(height), ha='center', va='bottom')

# Adding labels and title
plt.xlabel('Post')
plt.ylabel('Count')
plt.title('Likes for Different Posts')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

# Plotting likes
bars = plt.bar(posts['Post'], posts['Comments'], color='grey', label='Comments')

# Adding labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             '%d' % int(height), ha='center', va='bottom')

# Adding labels and title
plt.xlabel('Post')
plt.ylabel('Count')
plt.title('Comments for Different Posts')
plt.xticks(rotation=45)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
# Calculate likes, comments per category
df_plot = posts_plot.groupby('Post')[['Likes', 'Comments']].sum()

# Define the desired order of categories
desired_order = ['Before Co-Branding', 'Co-Branding', 'After Co-Branding']

# Sort the total_engagement_per_category DataFrame based on the desired order
df_plot = df_plot.reindex(desired_order)

df_plot
# Out:
#                      Likes  Comments
# Post
# Before Co-Branding  451079      6656
# Co-Branding         361981      8731
# After Co-Branding   398562      4603

# %% [markdown]
# Likes Analysis

# %%
# Plot the sum Likes per category
ax = df_plot['Likes'].plot(kind='bar', color='grey')
plt.title('Total Likes Per Category')
plt.xlabel('Post')
plt.ylabel('Likes')
plt.xticks(rotation=45)


# Add value labels to the bars
for i, v in enumerate(df_plot['Likes']):
    ax.text(i, v + 4000, str(v), ha='center', va='bottom')

plt.show()

# %%
# Calculate for each category
mean_likes = posts_plot.groupby('Post')['Likes'].agg(['mean'])
# Create a DataFrame with relevant data for comparison
comparison_likes = mean_likes.loc[['Before Co-Branding', 'Co-Branding', 'After Co-Branding']]

comparison_likes
# Out:
#                         mean
# Post
# Before Co-Branding   90215.8
# Co-Branding         180990.5
# After Co-Branding    79712.4

# %%
# Reordering the DataFrame based on the desired order of categories
desired_order = ['Before Co-Branding', 'Co-Branding', 'After Co-Branding']
mean_likes = mean_likes.reindex(desired_order)

# Plotting
ax = mean_likes.plot(kind='bar',color ="grey", figsize=(10, 6))
plt.title('Mean Likes for Each Category')
plt.xlabel('Category')
plt.ylabel('Likes')
plt.xticks(rotation=45)
plt.legend(title='Statistic')
for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), 
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %%
mean_likes = {
    'Before Co-Branding': 90215,
    'Co-Branding': 180990,
    'After Co-Branding': 79712
}

# Calculate the change in mean comments from 'Before Co-Branding' to 'Co-Branding'
change_comments_before_co_branding_percent = ((mean_likes['Co-Branding'] - mean_likes['Before Co-Branding']) / mean_likes['Before Co-Branding']) * 100
change_comments_co_before_branding_absolute = mean_likes['Co-Branding'] - mean_likes['Before Co-Branding']

# Calculate the change in mean comments  from 'Co-Branding' to 'After Co-Branding'
change_comments_after_co_branding_percent = ((mean_likes['After Co-Branding'] - mean_likes['Co-Branding']) / mean_likes['Co-Branding']) * 100
change_comments_after_co_branding_absolute = mean_likes['After Co-Branding'] - mean_likes['Co-Branding']

print("Change in mean likes from 'Before Co-Branding' to 'Co-Branding': {:.2f}% ({:.2f} comments)".format(change_comments_before_co_branding_percent, change_comments_co_before_branding_absolute))
print("Change in mean likes from 'Co-Branding' to 'After Co-Branding': {:.2f}% ({:.2f} comments)".format(change_comments_after_co_branding_percent, change_comments_after_co_branding_absolute))
# Out:
# Change in mean likes from 'Before Co-Branding' to 'Co-Branding': 100.62% (90775.00 comments)
# Change in mean likes from 'Co-Branding' to 'After Co-Branding': -55.96% (-101278.00 comments)

# %%
# PLOTTING LIKES CHANGE

# Calculate the changes in mean likes
changes_percent_likes = {
    'Before to Co-Branding': ((mean_likes['Co-Branding'] - mean_likes['Before Co-Branding']) / mean_likes['Before Co-Branding']) * 100,
    'Co-Branding to After': ((mean_likes['After Co-Branding'] - mean_likes['Co-Branding']) / mean_likes['Co-Branding']) * 100
}

changes_absolute_likes = {
    'Before Co-Branding': mean_likes['Co-Branding'] - mean_likes['Before Co-Branding'],
    'After Co-Branding': mean_likes['After Co-Branding'] - mean_likes['Co-Branding']
}

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Bar plot for percentage changes
ax[0].bar(changes_percent_likes.keys(), changes_percent_likes.values(), color=['grey', 'grey'])
ax[0].set_ylabel('Percentage Change')
ax[0].set_title('Percentage Change in Mean Likes')
for i, v in enumerate(changes_percent_likes.values()):
    ax[0].text(i, v, f"{v:.2f}%", ha='center', va='bottom')

# Bar plot for absolute changes
ax[1].bar(changes_absolute_likes.keys(), changes_absolute_likes.values(), color=['grey', 'grey'])
ax[1].set_ylabel('Absolute Change')
ax[1].set_title('Absolute Change in Mean Likes')
for i, v in enumerate(changes_absolute_likes.values()):
    ax[1].text(i, v, f"{v:.2f}", ha='center', va='bottom')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# Comments

# %%
# Plot the sum Comments per category
ax = df_plot['Likes'].plot(kind='bar', color='grey')
plt.title('Total Comments Per Category')
plt.xlabel('Post')
plt.ylabel('Comments')
plt.xticks(rotation=45)

# Add value labels to the bars at the end of each bar
for i, v in enumerate(df_plot['Comments']):
    ax.text(i, df_plot['Likes'].iloc[i] + 3000, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# Comments Analysis

# %%
# Calculate for each category
mean_comments = posts_plot.groupby('Post')['Comments'].agg(['mean'])
# Create a DataFrame with relevant data for comparison
comparison_comments = mean_comments.loc[['Before Co-Branding', 'Co-Branding', 'After Co-Branding']]
comparison_comments
# Out:
#                       mean
# Post
# Before Co-Branding  1331.2
# Co-Branding         4365.5
# After Co-Branding    920.6

# %%
# Reordering the DataFrame based on the desired order of categories
desired_order = ['Before Co-Branding', 'Co-Branding', 'After Co-Branding']
mean_comments = mean_comments.reindex(desired_order)

# Plotting
ax = mean_comments.plot(kind='bar',color ="grey", figsize=(10, 6))
plt.title('Mean Comments for Each Category')
plt.xlabel('Category')
plt.ylabel('Comments')
plt.xticks(rotation=45)
plt.legend(title='Statistic')

for p in ax.patches:
    ax.annotate(f"{int(p.get_height())}", 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), 
                textcoords='offset points')
plt.tight_layout()
plt.show()

# %%
mean_comments = {
    'Before Co-Branding': 1331,
    'Co-Branding': 4365,
    'After Co-Branding': 920
}

# Calculate the change in mean comments from 'Before Co-Branding' to 'Co-Branding'
change_comments_before_co_branding_percent = ((mean_comments['Co-Branding'] - mean_comments['Before Co-Branding']) / mean_comments['Before Co-Branding']) * 100
change_comments_co_before_branding_absolute = mean_comments['Co-Branding'] - mean_comments['Before Co-Branding']

# Calculate the change in mean comments  from 'Co-Branding' to 'After Co-Branding'
change_comments_after_co_branding_percent = ((mean_comments['After Co-Branding'] - mean_comments['Co-Branding']) / mean_comments['Co-Branding']) * 100
change_comments_after_co_branding_absolute = mean_comments['After Co-Branding'] - mean_comments['Co-Branding']

print("Change in mean comments from 'Before Co-Branding' to 'Co-Branding': {:.2f}% ({:.2f} comments)".format(change_comments_before_co_branding_percent, change_comments_co_before_branding_absolute))
print("Change in mean comments from 'Co-Branding' to 'After Co-Branding': {:.2f}% ({:.2f} comments)".format(change_comments_after_co_branding_percent, change_comments_after_co_branding_absolute))
# Out:
# Change in mean comments from 'Before Co-Branding' to 'Co-Branding': 227.95% (3034.00 comments)
# Change in mean comments from 'Co-Branding' to 'After Co-Branding': -78.92% (-3445.00 comments)

# %%
# PLOTTING LIKES CHANGE

# Calculate the changes in median likes
changes_percent_comments = {
    'Before to Co-Branding': ((mean_comments['Co-Branding'] - mean_comments['Before Co-Branding']) / mean_comments['Before Co-Branding']) * 100,
    'Co-Branding to After': ((mean_comments['After Co-Branding'] - mean_comments['Co-Branding']) / mean_comments['Co-Branding']) * 100
}

changes_absolute_comments = {
    'Before Co-Branding': mean_comments['Co-Branding'] - mean_comments['Before Co-Branding'],
    'After Co-Branding': mean_comments['After Co-Branding'] - mean_comments['Co-Branding']
}

# Plotting
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Bar plot for percentage changes
ax[0].bar(changes_percent_comments.keys(), changes_percent_comments.values(), color=['grey', 'grey'])
ax[0].set_ylabel('Percentage Change')
ax[0].set_title('Percentage Change in Mean Comments')
for i, v in enumerate(changes_percent_comments.values()):
    ax[0].text(i, v, f"{v:.2f}%", ha='center', va='bottom')

# Bar plot for absolute changes
ax[1].bar(changes_absolute_comments.keys(), changes_absolute_comments.values(), color=['grey', 'grey'])
ax[1].set_ylabel('Absolute Change')
ax[1].set_title('Absolute Change in Mean Comments')
for i, v in enumerate(changes_absolute_comments.values()):
    ax[1].text(i, v, f"{v:.2f}", ha='center', va='bottom')

# Show plot
plt.tight_layout()
plt.show()
